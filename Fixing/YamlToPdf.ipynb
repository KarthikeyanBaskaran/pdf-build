# %%
from testingsemantic import generate_pdf_from_yaml, load_config
import yaml

# %%
config = load_config()
with open('output.yaml', 'r') as f:
    resume_data = yaml.safe_load(f)
# Out:
# 2025-07-15 17:56:27,539 - INFO - Loading configuration from 'config.yaml'...

# %%
generate_pdf_from_yaml(resume_data,config)
# Out:
# 2025-07-15 17:57:11,073 - INFO - Using theme from directory: '.'
# 2025-07-15 17:57:11,119 - INFO - HTML content rendered successfully.
# 2025-07-15 17:57:11,180 - WARNING - Ignored `width: fit-content` at 94:5, invalid value.
# 2025-07-15 17:57:11,348 - WARNING - Ignored `width: fit-content` at 94:5, invalid value.
# 2025-07-15 17:57:11,723 - DEBUG - Reading 'maxp' table from disk
# 2025-07-15 17:57:11,724 - DEBUG - Decompiling 'maxp' table
# 2025-07-15 17:57:11,726 - DEBUG - Took 0.003s to load 'maxp'
# 2025-07-15 17:57:11,727 - DEBUG - Took 0.000s to prune 'maxp'
# 2025-07-15 17:57:11,728 - INFO - maxp pruned
# 2025-07-15 17:57:11,731 - DEBUG - Reading 'cmap' table from disk
# 2025-07-15 17:57:11,732 - DEBUG - Decompiling 'cmap' table
# 2025-07-15 17:57:11,733 - DEBUG - Reading 'post' table from disk
# 2025-07-15 17:57:11,737 - DEBUG - Decompiling 'post' table
# 2025-07-15 17:57:11,746 - DEBUG - Took 0.015s to load 'cmap'
# ...
